# %% [markdown]
# <a href="https://colab.research.google.com/github/dggasque/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-10-01 22:26:38--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [        <=>         ]  21.62M  1.65MB/s    in 13s
#
# 2019-10-01 22:26:52 (1.64 MB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22667400]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
import pandas as pd

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# 2   11.31%       580.28     B        B3               Compliance Director
# 3   12.98%       350.32     B        B5        Program Support Assistant
# 4   12.98%       796.00     B        B5  Sr. Vice President -Risk Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# desc                                          128412
# member_id                                     128412
# url                                           128412
# orig_projected_additional_accrued_interest    128345
# hardship_type                                 128343
# hardship_last_payment_amount                  128343
# hardship_payoff_balance_amount                128343
# hardship_reason                               128343
# hardship_loan_status                          128343
# hardship_dpd                                  128343
# hardship_length                               128343
# payment_plan_start_date                       128343
# hardship_end_date                             128343
# hardship_start_date                           128343
# hardship_amount                               128343
# deferral_term                                 128343
# hardship_status                               128343
# ...

# %%
# Drop columns that are made of all NaN values
df_dropped = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      25000        25000          25000.0   60 months   16.14%       609.82
# 2      26500        26500          26500.0   60 months   11.31%       580.28
# 3      10400        10400          10400.0   36 months   12.98%       350.32
# 4      35000        35000          35000.0   60 months   12.98%       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        bus driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5        Program Support Assistant   10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_dropped['int_rate'][:10]
# Out:
# 0     14.47%
# 1     16.14%
# 2     11.31%
# 3     12.98%
# 4     12.98%
# 5      7.56%
# 6     17.97%
# 7     14.47%
# 8     11.80%
# 9     17.97%
# Name: int_rate, dtype: object

# %%
df_dropped.dtypes[:10]
# Out:
# loan_amnt            int64
# funded_amnt          int64
# funded_amnt_inv    float64
# term                object
# int_rate            object
# installment        float64
# grade               object
# sub_grade           object
# emp_title           object
# emp_length          object
# dtype: object

# %%
def int_rate_to_float(mystring):
  return float(mystring.strip().strip('%'))

# %%
df_dropped['int_rate'].apply(int_rate_to_float)[:10]
# Out:
# 0    14.47
# 1    16.14
# 2    11.31
# 3    12.98
# 4    12.98
# 5     7.56
# 6    17.97
# 7    14.47
# 8    11.80
# 9    17.97
# Name: int_rate, dtype: float64

# %%
df_dropped['int_rate'] = df_dropped['int_rate'].apply(int_rate_to_float)

# %%
#Clean emp_title
df_dropped['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#Find number of unique job titles
len(df_dropped['emp_title'].value_counts())
# Out:
# 43892

# %%
# Clean the title and handle missing values
import numpy as np

examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

[clean_title(item) for item in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df_dropped['emp_title'] = df_dropped['emp_title'].apply(clean_title)

# %%
df_dropped['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
len(df_dropped['emp_title'].value_counts())
# Out:
# 34902

# %%
#Create emp_title_manager
df_dropped['emp_title_manager'] = df_dropped['emp_title'].str.contains('Manager')
df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
condition = (df_dropped['emp_title_manager'] == True)

managers = df_dropped[df_dropped['emp_title_manager'] == True]
print(managers.shape)
managers.head()
# Out:
# (17882, 141)
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 1       25000        25000          25000.0   60 months     16.14
# 4       35000        35000          35000.0   60 months     12.98
# 8       12000        12000          12000.0   36 months     11.80
# 16      12000        12000          12000.0   36 months     16.14
# 18      20400        20400          20400.0   60 months     10.33
#
#     installment grade sub_grade                         emp_title emp_length  \
# 1        609.82     C        C4                Production Manager    5 years
# 4        796.00     B        B5  Sr. Vice President -Risk Manager    7 years
# 8        397.43     B        B4            Transportation Manager  10+ years
# 16       422.72     C        C4             Sales Account Manager    4 years
# 18       436.76     B        B1                    Bakery Manager  10+ years
#
#    home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
(df_dropped['emp_title_manager'] == False) & (df_dropped['home_ownership']=="OWN")
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24         True
# 25        False
# 26        False
# 27         True
# 28        False
# 29        False
# 30        False
# 31         True
# 32        False
# 33        False
# 34        False
# 35        False
# 36        False
# 37        False
# 38        False
# 39        False
# 40        False
# 41        False
# 42        False
# 43        False
# 44        False
# 45        False
# 46        False
# 47        False
# 48        False
# 49        False
# 50        False
# 51        False
# 52        False
# 53         True
# 54        False
# ...

# %%
plebians = df_dropped[(df_dropped['emp_title_manager'] == False) & (df_dropped['home_ownership'] == 'MORTGAGE')]
print(plebians.shape)
plebians.head()
# Out:
# (53930, 141)
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 2       26500        26500          26500.0   60 months     11.31
# 3       10400        10400          10400.0   36 months     12.98
# 5       20000        20000          20000.0   36 months      7.56
# 6       13000        13000          13000.0   36 months     17.97
# 11       7000         7000           6975.0   36 months     10.72
#
#     installment grade sub_grade                  emp_title emp_length  \
# 2        580.28     B        B3        Compliance Director  10+ years
# 3        350.32     B        B5  Program Support Assistant  10+ years
# 5        622.68     A        A3                    Teacher  10+ years
# 6        469.79     D        D1       Help Tech Supervisor  10+ years
# 11       228.25     B        B2           Business Analyst   < 1 year
#
#    home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
managers['int_rate'].mean()
# Out:
# 12.760582149647117

# %%
plebians['int_rate'].mean()
# Out:
# 12.576722603373335

# %%
import seaborn as sns

sns.kdeplot(plebians['int_rate'])
sns.kdeplot(managers['int_rate']);

# %%
sns.distplot(plebians['int_rate'])
sns.distplot(managers['int_rate']);

# %% [markdown]
# Work with Dates

# %%
list(df_dropped.columns)
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
# ...

# %%
[col for col in df_dropped if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df_dropped.dtypes[:15]
# Out:
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# sub_grade               object
# emp_title               object
# emp_length              object
# home_ownership          object
# annual_inc             float64
# verification_status     object
# issue_d                 object
# loan_status             object
# dtype: object

# %%
df_dropped['issue_d'][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
df_dropped['issue_d'] = pd.to_datetime(df_dropped['issue_d'], infer_datetime_format=True)
df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_dropped['issue_d'][:10]
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# 5   2018-12-01
# 6   2018-12-01
# 7   2018-12-01
# 8   2018-12-01
# 9   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df_dropped.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df_dropped['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df_dropped['issue_d'].dt.year[:15]
# Out:
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# 5     2018
# 6     2018
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# Name: issue_d, dtype: int64

# %%
df_dropped['issue_year'] = df_dropped['issue_d'].dt.year

# %%
df_dropped['issue_month'] = df_dropped['issue_d'].dt.month

# %%
df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %% [markdown]
# ## Convert the term column from string to integer.

# %%
#Print out a few rows of the 'term' column 
df_dropped['term'][:10]
# Out:
# 0     36 months
# 1     60 months
# 2     60 months
# 3     36 months
# 4     60 months
# 5     36 months
# 6     36 months
# 7     60 months
# 8     36 months
# 9     60 months
# Name: term, dtype: object

# %%
# Remove 'months' and spaces from a string and convert it to int

term = ' 36 months'
int(term.strip('months').strip())
# Out:
# 36

# %%
# Define function that removes 'months' and spaces from a string and converts it to int
def term_str_to_int(str):
  return int(str.strip('months').strip())

# %%
# Apply term_str_to_int and save output to term column

df_dropped['term'] = df_dropped['term'].apply(term_str_to_int)

df_dropped['term'][:5]
# Out:
# 0    36
# 1    60
# 2    60
# 3    36
# 4    60
# Name: term, dtype: int64

# %% [markdown]
# ##Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
# Define function that takes value from loan_status
def loan_status_check(loan_status):
  if loan_status == 'Current' or loan_status == 'Fully Paid':
    return 1
  else:
    return 0

# %%
# Create new column by applying function to loan_status column

df_dropped['loan_status_is_great'] = df_dropped['loan_status'].apply(loan_status_check)

df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_dropped['loan_status_is_great'].value_counts()
# Out:
# 1    121705
# 0      6707
# Name: loan_status_is_great, dtype: int64

# %% [markdown]
# ##Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
df_dropped['last_pymnt_d'][:10]
# Out:
# 0    Sep-2019
# 1    Apr-2019
# 2    Sep-2019
# 3    Sep-2019
# 4    Apr-2019
# 5    Feb-2019
# 6    Sep-2019
# 7    Sep-2019
# 8    Sep-2019
# 9    Sep-2019
# Name: last_pymnt_d, dtype: object

# %%
df_dropped['last_pymnt_d'] = pd.to_datetime(df_dropped['last_pymnt_d'], infer_datetime_format=True)
df_dropped['last_pymnt_d'][:10]
# Out:
# 0   2019-09-01
# 1   2019-04-01
# 2   2019-09-01
# 3   2019-09-01
# 4   2019-04-01
# 5   2019-02-01
# 6   2019-09-01
# 7   2019-09-01
# 8   2019-09-01
# 9   2019-09-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df_dropped['last_pymnt_d_month'] = df_dropped['last_pymnt_d'].dt.month

# %%
df_dropped['last_pymnt_d_year'] = df_dropped['last_pymnt_d'].dt.year

# %%
df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-10-01 22:35:53--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.17.139
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.17.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz.1’
#
# instacart_online_gr 100%[===================>] 196.03M  45.1MB/s    in 4.8s
#
# 2019-10-01 22:35:58 (41.0 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz.1’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
order_products_prior = pd.read_csv('order_products__prior.csv')
order_products_train = pd.read_csv('order_products__train.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')

print(aisles.head())
print(departments.head())
print(order_products_prior.head())
print(order_products_train.head()) 
print(orders.head()) 
print(products.head())
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# ...

# %%
# Engineer new feature "How often an item is purchased"

# Create dataframe with count of purchased by product_id
# First count Items in orders
purchase_counts = order_products_train['product_id'].value_counts()
# Convert Series to Datarame
purchase_counts = pd.DataFrame(purchase_counts)
# Reset Index
purchase_counts = purchase_counts.reset_index()
#Add column names
purchase_counts.columns = ['product_id', 'number_purchased']

purchase_counts.head()
# Out:
#    product_id  number_purchased
# 0       24852             18726
# 1       13176             15480
# 2       21137             10894
# 3       21903              9784
# 4       47626              8135

# %%
#Join feature with product information

products_ammended = products.join(purchase_counts.set_index('product_id'), on = 'product_id')

products_ammended.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  number_purchased
# 0             19              76.0
# 1             13               4.0
# 2              7               6.0
# 3              1              22.0
# 4             13               1.0

# %% [markdown]
# ##LendingClub Stretch Goal

# %%
#Convert String in revol_util column into float

df_dropped['revol_util_as_float'] = df_dropped['revol_util'].str.strip('%').astype(float)

df_dropped.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
# Modify the emp_title column to replace titles with 'Other' if the title is not in the top 20

df_dropped['emp_title'].value_counts()[:21]
# Out:
# Unknown                     20947
# Teacher                      2557
# Manager                      2395
# Registered Nurse             1418
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Rn                            834
# Office Manager                805
# Sales                         803
# General Manager               791
# Project Manager               720
# Owner                         625
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Nurse                         425
# Technician                    420
# Engineer                      412
# Administrative Assistant      409
# Name: emp_title, dtype: int64

# %%
#Recategorize Registered Nurse, Nurse, and R 

def change_RN(string):
  if string == 'Rn' or string == 'Registered Nurse':
    return 'Nurse'
  else:
    return string

df_dropped['emp_title'] = df_dropped['emp_title'].apply(change_RN)

df_dropped['emp_title'].value_counts()[:21]
# Out:
# Unknown                     20947
# Nurse                        2677
# Teacher                      2557
# Manager                      2395
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Office Manager                805
# Sales                         803
# General Manager               791
# Project Manager               720
# Owner                         625
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Technician                    420
# Engineer                      412
# Administrative Assistant      409
# Store Manager                 398
# Mechanic                      391
# Name: emp_title, dtype: int64

# %%
#Combine Manager and General Manager
def combine_manager(string):
  if string == 'General Manager':
    return 'Manager'
  else:
    return string


df_dropped['emp_title'] = df_dropped['emp_title'].apply(combine_manager)

df_dropped['emp_title'].value_counts()[:21]
# Out:
# Unknown                     20947
# Manager                      3186
# Nurse                        2677
# Teacher                      2557
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Office Manager                805
# Sales                         803
# Project Manager               720
# Owner                         625
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Technician                    420
# Engineer                      412
# Administrative Assistant      409
# Store Manager                 398
# Mechanic                      391
# Assistant Manager             383
# Name: emp_title, dtype: int64

# %%
top_20 = df_dropped['emp_title'].value_counts()[1:21].index.tolist()
top_20
# Out:
# ['Manager',
#  'Nurse',
#  'Teacher',
#  'Driver',
#  'Supervisor',
#  'Truck Driver',
#  'Office Manager',
#  'Sales',
#  'Project Manager',
#  'Owner',
#  'Director',
#  'Operations Manager',
#  'Sales Manager',
#  'Police Officer',
#  'Technician',
#  'Engineer',
#  'Administrative Assistant',
#  'Store Manager',
#  'Mechanic',
#  'Assistant Manager']

# %%
def title_in_top_20(string):
  if string in top_20:
    return string
  else:
    return 'Other'

test = ['Nurse', 'Firefighter', 'Engineer', 'Unkown', 'Owner']

[title_in_top_20(title) for title in test]
# Out:
# ['Nurse', 'Other', 'Engineer', 'Other', 'Owner']

# %%
df_dropped['emp_title'] = df_dropped['emp_title'].apply(title_in_top_20)

df_dropped['emp_title'].value_counts()
# Out:
# Other                       109307
# Manager                       3186
# Nurse                         2677
# Teacher                       2557
# Driver                        1258
# Supervisor                    1160
# Truck Driver                   920
# Office Manager                 805
# Sales                          803
# Project Manager                720
# Owner                          625
# Director                       523
# Operations Manager             518
# Sales Manager                  500
# Police Officer                 440
# Technician                     420
# Engineer                       412
# Administrative Assistant       409
# Store Manager                  398
# Mechanic                       391
# Assistant Manager              383
# Name: emp_title, dtype: int64
